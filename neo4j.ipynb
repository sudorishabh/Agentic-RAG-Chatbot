# %%
pip install neo4j
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting neo4j
#   Downloading neo4j-6.2.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pytz (from neo4j)
#   Downloading pytz-2026.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Downloading neo4j-6.2.0-py3-none-any.whl (327 kB)
# Downloading pytz-2026.3.post1-py2.py3-none-any.whl (508 kB)
# Installing collected packages: pytz, neo4j
#
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    -------------------- ------------------- 1/2 [neo4j]
#    -------------------- ------------------- 1/2 [neo4j]
#    -------------------- ------------------- 1/2 [neo4j]
#    -------------------- ------------------- 1/2 [neo4j]
#    -------------------- ------------------- 1/2 [neo4j]
#    -------------------- ------------------- 1/2 [neo4j]
#    -------------------- ------------------- 1/2 [neo4j]
#    -------------------- ------------------- 1/2 [neo4j]
#    -------------------- ------------------- 1/2 [neo4j]
#    -------------------- ------------------- 1/2 [neo4j]
#    ---------------------------------------- 2/2 [neo4j]
#
# Successfully installed neo4j-6.2.0 pytz-2026.3.post1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from neo4j import GraphDatabase

# %%
NEO4J_URI="neo4j+s://5b7e7e19.databases.neo4j.io"
NEO4J_USERNAME="5b7e7e19"
NEO4J_PASSWORD="MY2O4N_yl949clV2FLIce3WUgK7WVEmUptxEhiKG2Fc"

# %%
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %%
driver.verify_connectivity()

# %%
query = """
CREATE (e:Person {
    name: $name, age: $age
})
RETURN e

"""

# %%
driver.execute_query(query,
                      name="Rishabh Negi", 
                      age=30)
# Out:
# EagerResult(records=[<Record e=<Node element_id='4:0d991305-17ac-49ac-801f-1a872351e17e:2' labels=frozenset({'Person'}) properties={'name': 'Rishabh Negi', 'age': 30}>>], summary=<neo4j._work.summary.ResultSummary object at 0x000002539C762210>, keys=['e'])

# %%
query = """
CREATE (e:Address {
    city: $city, country: $country
})
RETURN e

"""

# %%
driver.execute_query(query,
                      city="New York", 
                      country="USA")
# Out:
# EagerResult(records=[<Record e=<Node element_id='4:0d991305-17ac-49ac-801f-1a872351e17e:1' labels=frozenset({'Address'}) properties={'country': 'USA', 'city': 'New York'}>>], summary=<neo4j._work.summary.ResultSummary object at 0x000002539CFA4410>, keys=['e'])

# %%
records, summary, key = driver.execute_query(
"""
MATCH (p:Person)

RETURN p.name, p.age

""")

# %%
records
# Out:
# [<Record p.name='John Doe' p.age=30>, <Record p.name='Rishabh Negi' p.age=30>]
